# %%
# импорт бибилиотек 
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

from matplotlib import pyplot as plt

# %%
# Чтобы часть столбцов в дальнейшем не скрывалась, настроим принудительное отображение
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ##  Изучение общей информации о данных

# %%
# загружаем данные из эксель файла
excel_data_1= pd.read_excel('/Users/popov/Downloads/Новая таблица 1тестовое данные.xlsx')
df = pd.DataFrame(excel_data_1)
display(df.head(10))
display(df.info())
# Out:
#    Unnamed: 0 Unnamed: 1  \
# 0         NaN        NaN
# 1         NaN     Регион
# 2         NaN     МОСКВА
# 3         NaN     МОСКВА
# 4         NaN     МОСКВА
# 5         NaN     МОСКВА
# 6         NaN     МОСКВА
# 7         NaN     МОСКВА
# 8         NaN     МОСКВА
# 9         NaN     МОСКВА
#
#                                                                        Unnamed: 2  \
# 0                                                                             NaN
# 1                                                                      Группа АТХ
# 2                   ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ СЕРДЕЧНО-СОСУДИСТОЙ СИСТЕМЫ
# 3                    ПРЕПАРАТЫ, ВЛИЯЮЩИЕ НА ПИЩЕВАРИТЕЛЬНЫЙ ТРАКТ И ОБМЕН ВЕЩЕСТВ
# 4                               ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ НЕРВНОЙ СИСТЕМЫ
# 5                   ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ СЕРДЕЧНО-СОСУДИСТОЙ СИСТЕМЫ
# 6                               ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ НЕРВНОЙ СИСТЕМЫ
# 7         ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ МОЧЕПОЛОВОЙ СИСТЕМЫ И ПОЛОВЫЕ ГОРМОНЫ
# 8  ГОРМОНАЛЬНЫЕ ПРЕПАРАТЫ ДЛЯ СИСТЕМНОГО ИСПОЛЬЗОВАНИЯ (ИСКЛЮЧАЯ ПОЛОВЫЕ ГОРМОНЫ)
# 9                    ПРЕПАРАТЫ, ВЛИЯЮЩИЕ НА ПИЩЕВАРИТЕЛЬНЫЙ ТРАКТ И ОБМЕН ВЕЩЕСТВ
#
#           Unnamed: 3  \
# 0                NaN
# 1                МНН
# 2          НИФЕДИПИН
# 3          ОМЕПРАЗОЛ
# 4         ПАРОКСЕТИН
# 5        ПЕРИНДОПРИЛ
# 6          ПИРАЦЕТАМ
# 7         ТАМСУЛОЗИН
# 8           ТИАМАЗОЛ
# 9  ТИОКТОВАЯ КИСЛОТА
#
#                                                        Unnamed: 4 Unnamed: 5  \
# 0                                                             NaN        NaN
# 1                                             Лекарственная форма  Дозировка
# 2  ТАБЛЕТКИ С ПРОЛОНГИРОВАННЫМ ВЫСВОБОЖДЕНИЕМ, ПОКРЫТЫЕ ОБОЛОЧКОЙ      30 мг
# 3                                    ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ      20 мг
# 4                                    ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ      20 мг
# 5                                    ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ       4 мг
# 6                                    ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ     400 мг
# 7                       КАПСУЛЫ С МОДИФИЦИРОВАННЫМ ВЫСВОБОЖДЕНИЕМ     0.4 мг
# 8                                                        ТАБЛЕТКИ       5 мг
# 9                                             РАСТВОР ДЛЯ ИНФУЗИЙ   12 мг/мл
#
#                 Unnamed: 6         Unnamed: 7             Unnamed: 8
# 0                      NaN                NaN                    NaN
# 1  Обеспеченность, месяцев  Остатки, упаковок                    Тип
# 2                      1.8              26896  анализ проведен ранее
# 3                      2.9                455  анализ проведен ранее
# 4                      2.5               6295                  новое
# 5                      0.1                248  анализ проведен ранее
# 6                      2.5               1495  анализ проведен ранее
# 7                      1.8              44552  анализ проведен ранее
# 8                      2.6                753                  новое
# 9                      2.1               1520                  новое
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 532 entries, 0 to 531
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   Unnamed: 1  531 non-null    object
#  2   Unnamed: 2  531 non-null    object
#  3   Unnamed: 3  531 non-null    object
#  4   Unnamed: 4  531 non-null    object
#  5   Unnamed: 5  523 non-null    object
#  6   Unnamed: 6  531 non-null    object
#  7   Unnamed: 7  531 non-null    object
#  8   Unnamed: 8  531 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 37.5+ KB
# None

# %% [markdown]
# <div class="alert alert-info"> Первичная выгрузка данных выявила неудобный формат таблицы для работы . В кодах ниже приведем таблицу к нужному виду озаглавив столбцы и  убрав лишние строки без информации

# %% [markdown]
# ##  Предобработка данных

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8'],
#       dtype='object')

# %%
df = df.rename(columns={'Unnamed: 1': 'Регион', 
                        'Unnamed: 2': 'Группа АТХ',
                        'Unnamed: 3': 'МНН',
                        'Unnamed: 4': 'Лекарственная форма',
                        'Unnamed: 5': 'Дозировка',
                        'Unnamed: 6': 'Обеспеченность, месяцев',
                        'Unnamed: 7': 'Остатки упаковок',
                        'Unnamed: 8': 'Тип' })

# %%
df.drop(labels = [0,1],axis = 0, inplace = True)

# %%
df.drop (df.columns [[0]], axis= 1 , inplace= True )

# %%
df
# Out:
#      Регион                                                     Группа АТХ  \
# 2    МОСКВА  ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ СЕРДЕЧНО-СОСУДИСТОЙ СИСТЕМЫ
# 3    МОСКВА   ПРЕПАРАТЫ, ВЛИЯЮЩИЕ НА ПИЩЕВАРИТЕЛЬНЫЙ ТРАКТ И ОБМЕН ВЕЩЕСТВ
# 4    МОСКВА              ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ НЕРВНОЙ СИСТЕМЫ
# 5    МОСКВА  ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ СЕРДЕЧНО-СОСУДИСТОЙ СИСТЕМЫ
# 6    МОСКВА              ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ НЕРВНОЙ СИСТЕМЫ
# ..      ...                                                            ...
# 527  МОСКВА      ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ КОСТНО-МЫШЕЧНОЙ СИСТЕМЫ
# 528  МОСКВА              ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ НЕРВНОЙ СИСТЕМЫ
# 529  МОСКВА                   ПРЕПАРАТЫ, ВЛИЯЮЩИЕ НА КРОВЕТВОРЕНИЕ И КРОВЬ
# 530  МОСКВА        ПРОТИВОМИКРОБНЫЕ ПРЕПАРАТЫ ДЛЯ СИСТЕМНОГО ИСПОЛЬЗОВАНИЯ
# 531  МОСКВА      ПРЕПАРАТЫ ДЛЯ ЛЕЧЕНИЯ ЗАБОЛЕВАНИЙ КОСТНО-МЫШЕЧНОЙ СИСТЕМЫ
#
#                                                   МНН  \
# 2                                           НИФЕДИПИН
# 3                                           ОМЕПРАЗОЛ
# 4                                          ПАРОКСЕТИН
# 5                                         ПЕРИНДОПРИЛ
# 6                                           ПИРАЦЕТАМ
# ..                                                ...
# 527                                        КЕТОПРОФЕН
# 528                                         ЛОРАЗЕПАМ
# 529  ФАКТОР СВЕРТЫВАНИЯ КРОВИ VIII+ФАКТОР ВИЛЛЕБРАНДА
# 530                          АМИНОСАЛИЦИЛОВАЯ КИСЛОТА
# 531                                         ИБУПРОФЕН
#
#                                                 Лекарственная форма  \
# 2    ТАБЛЕТКИ С ПРОЛОНГИРОВАННЫМ ВЫСВОБОЖДЕНИЕМ, ПОКРЫТЫЕ ОБОЛОЧКОЙ
# 3                                      ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ
# 4                                      ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ
# 5                                      ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ
# 6                                      ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ
# ..                                                              ...
# 527                                         СУППОЗИТОРИИ РЕКТАЛЬНЫЕ
# 528                                    ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ
# 529               ЛИОФИЛИЗАТ ДЛЯ ПРИГОТОВЛЕНИЯ РАСТВОРА ДЛЯ ИНФУЗИЙ
# 530                                    ТАБЛЕТКИ, ПОКРЫТЫЕ ОБОЛОЧКОЙ
# 531                                     СУСПЕНЗИЯ ДЛЯ ПРИЕМА ВНУТРЬ
#
#            Дозировка Обеспеченность, месяцев Остатки упаковок  \
# 2              30 мг                     1.8            26896
# 3              20 мг                     2.9              455
# 4              20 мг                     2.5             6295
# 5               4 мг                     0.1              248
# 6             400 мг                     2.5             1495
# ..               ...                     ...              ...
# 527           160 мг                     0.3               11
# 528             1 мг                       0                0
# 529  1000 МЕ+1200 МЕ                       0                0
# 530           200 мг                     0.8                1
# 531         40 мг/мл                       1                9
#
#                        Тип
# 2    анализ проведен ранее
# 3    анализ проведен ранее
# 4                    новое
# 5    анализ проведен ранее
# 6    анализ проведен ранее
# ..                     ...
# 527  анализ проведен ранее
# 528  анализ проведен ранее
# 529                  новое
# 530                  новое
# 531                  новое
#
# [530 rows x 8 columns]

# %%
# подсчет пропусков
df.isna().sum()
# Out:
# Регион                     0
# Группа АТХ                 0
# МНН                        0
# Лекарственная форма        0
# Дозировка                  8
# Обеспеченность, месяцев    0
# Остатки упаковок           0
# Тип                        0
# dtype: int64

# %% [markdown]
# <div class="alert alert-info"> Имеются 8 пропусков в столбце дозировка , но  в данном случае нужно вручную анализировать и заполнять каждый

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530 entries, 2 to 531
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Регион                   530 non-null    object
#  1   Группа АТХ               530 non-null    object
#  2   МНН                      530 non-null    object
#  3   Лекарственная форма      530 non-null    object
#  4   Дозировка                522 non-null    object
#  5   Обеспеченность, месяцев  530 non-null    object
#  6   Остатки упаковок         530 non-null    object
#  7   Тип                      530 non-null    object
# dtypes: object(8)
# memory usage: 33.3+ KB

# %% [markdown]
# <div class="alert alert-info"> В столбцах обнаружен не соотвествующий формат числовых данных. Приведем данные к нужному виду в столбцах: 'Обеспеченность, месяцев' и 'Остатки упаковок'

# %%
# замена объектного типа данных  типа данных в столбце на  целочисленный 
df['Остатки упаковок']=df['Остатки упаковок'].astype('int')
display(df['Остатки упаковок'])
# Out:
# 2      26896
# 3        455
# 4       6295
# 5        248
# 6       1495
#        ...
# 527       11
# 528        0
# 529        0
# 530        1
# 531        9
# Name: Остатки упаковок, Length: 530, dtype: int32

# %%
# замена объектного типа данных  типа данных в столбце на вещественное число
df['Обеспеченность, месяцев']=df['Обеспеченность, месяцев'].astype('float')
display(df['Обеспеченность, месяцев'])
# Out:
# 2      1.8
# 3      2.9
# 4      2.5
# 5      0.1
# 6      2.5
#       ...
# 527    0.3
# 528    0.0
# 529    0.0
# 530    0.8
# 531    1.0
# Name: Обеспеченность, месяцев, Length: 530, dtype: float64

# %%
# приведем строки в столбцах к необходимому в задании формату
df['Регион']=df['Регион'].str.capitalize()
df['Группа АТХ']=df['Группа АТХ'].str.capitalize()
df['МНН']=df['МНН'].str.capitalize()
df['Лекарственная форма']=df['Лекарственная форма'].str.capitalize()
df.head(10)
# Out:
#     Регион  \
# 2   Москва
# 3   Москва
# 4   Москва
# 5   Москва
# 6   Москва
# 7   Москва
# 8   Москва
# 9   Москва
# 10  Москва
# 11  Москва
#
#                                                                         Группа АТХ  \
# 2                    Препараты для лечения заболеваний сердечно-сосудистой системы
# 3                     Препараты, влияющие на пищеварительный тракт и обмен веществ
# 4                                Препараты для лечения заболеваний нервной системы
# 5                    Препараты для лечения заболеваний сердечно-сосудистой системы
# 6                                Препараты для лечения заболеваний нервной системы
# 7          Препараты для лечения заболеваний мочеполовой системы и половые гормоны
# 8   Гормональные препараты для системного использования (исключая половые гормоны)
# 9                     Препараты, влияющие на пищеварительный тракт и обмен веществ
# 10                    Препараты, влияющие на пищеварительный тракт и обмен веществ
# 11                               Препараты для лечения заболеваний нервной системы
#
#                   МНН  \
# 2           Нифедипин
# 3           Омепразол
# 4          Пароксетин
# 5         Периндоприл
# 6           Пирацетам
# 7          Тамсулозин
# 8            Тиамазол
# 9   Тиоктовая кислота
# 10  Тиоктовая кислота
# 11           Трамадол
#
#                                                Лекарственная форма Дозировка  \
# 2   Таблетки с пролонгированным высвобождением, покрытые оболочкой     30 мг
# 3                                     Таблетки, покрытые оболочкой     20 мг
# 4                                     Таблетки, покрытые оболочкой     20 мг
# 5                                     Таблетки, покрытые оболочкой      4 мг
# 6                                     Таблетки, покрытые оболочкой    400 мг
# 7                        Капсулы с модифицированным высвобождением    0.4 мг
# 8                                                         Таблетки      5 мг
# 9                                              Раствор для инфузий  12 мг/мл
# 10                                    Таблетки, покрытые оболочкой    600 мг
# 11                                                         Капсулы     50 мг
#
#     Обеспеченность, месяцев  Остатки упаковок                    Тип
# 2                       1.8             26896  анализ проведен ранее
# 3                       2.9               455  анализ проведен ранее
# 4                       2.5              6295                  новое
# 5                       0.1               248  анализ проведен ранее
# 6                       2.5              1495  анализ проведен ранее
# 7                       1.8             44552  анализ проведен ранее
# 8                       2.6               753                  новое
# 9                       2.1              1520                  новое
# 10                      2.4             10966  анализ проведен ранее
# 11                      2.8              9922  анализ проведен ранее

# %% [markdown]
# ## Исследовательский анализ данных

# %%
# Просмотр уникальных названий в столбце
df['Группа АТХ'].sort_values().unique()
# Out:
# array(['Гормональные препараты для системного использования (исключая половые гормоны)',
#        'Препараты для лечения заболеваний кожи',
#        'Препараты для лечения заболеваний костно-мышечной системы',
#        'Препараты для лечения заболеваний мочеполовой системы и половые гормоны',
#        'Препараты для лечения заболеваний нервной системы',
#        'Препараты для лечения заболеваний органов чувств',
#        'Препараты для лечения заболеваний респираторной системы',
#        'Препараты для лечения заболеваний сердечно-сосудистой системы',
#        'Препараты, влияющие на кроветворение и кровь',
#        'Препараты, влияющие на пищеварительный тракт и обмен веществ',
#        'Противомикробные препараты для системного использования',
#        'Противоопухолевые препараты и иммуномодуляторы',
#        'Противопаразитарные препараты, инсектициды и репелленты',
#        'Прочие лекарственные препараты'], dtype=object)

# %%
#сводная таблица остатков упаковок по группам препаратов отсортированныя по убыванию 
df_gr=df.pivot_table(index='Группа АТХ', values='Остатки упаковок',aggfunc='sum').sort_values(by='Остатки упаковок', ascending=False)
df_gr
# Out:
#                                                                                 Остатки упаковок
# Группа АТХ
# Препараты для лечения заболеваний сердечно-сосудистой системы                            1077822
# Препараты, влияющие на пищеварительный тракт и обмен веществ                             1070025
# Противомикробные препараты для системного использования                                   700513
# Препараты для лечения заболеваний нервной системы                                         276493
# Противоопухолевые препараты и иммуномодуляторы                                            229662
# Препараты для лечения заболеваний респираторной системы                                   215843
# Препараты для лечения заболеваний костно-мышечной системы                                 108583
# Препараты, влияющие на кроветворение и кровь                                              101751
# Препараты для лечения заболеваний мочеполовой системы и половые гормоны                    88524
# Прочие лекарственные препараты                                                             44181
# Гормональные препараты для системного использования (исключая половые гормоны)             38491
# Препараты для лечения заболеваний кожи                                                      9595
# Препараты для лечения заболеваний органов чувств                                             504
# Противопаразитарные препараты, инсектициды и репелленты                                        0

# %%
df_gr.reset_index().plot(x='Группа АТХ', y= 'Остатки упаковок', kind='bar', figsize=(15,5), grid=True, title='Количество упаковок по группам АТХ ')


plt.show()

# %%
df.to_excel('df.xlsx', index=False)

# %%
Ссылка на дашборд

# %% [markdown]
# https://public.tableau.com/shared/KB2J8NBMZ?:display_count=n&:origin=viz_share_link
